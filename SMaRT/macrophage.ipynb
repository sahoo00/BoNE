# %%
import matplotlib
# %matplotlib inline
try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3

import MacUtils as mut
reload(mut)
# Out:
# <module 'MacUtils' from '/mnt/booleanfs2/sahoo/BoNE/SMaRT/MacUtils.py'>

# %%
reload(mut)
wt1, l1 = mut.getCls13a14a3()
#wt1, l1 = mut.getCls13()
#wt1, l1 = mut.getCls14a3()
#l1 = mut.getGroupsMm(l1)
#l1 = mut.getGroupsMmv1(l1)
ana = mut.MacAnalysis()
ana.getGEOMacAnn()
#ana.getXue2014(4)
#ana.getImmGenULI(4)
#ana.getDas2018()
#ana.getRochaResende()
#ana.getDaniel2018()
#ana.getHutchins2015TPM(4)
#ana.getOlmosSerrano2016()
#ana.getArijs2018(3)
#ana.getGoldmann2015(3)
#ana.getUckelmann2020Mm(2)
#ana.getElDahr2019(2)
#ana.getSimpson2019(2)
#ana.getDAmore2018()
ana.orderDataDf(l1, wt1)
#ana.normGene("DBP")
fig = mut.plotViolinBar(ana, "Mac")
ana.getMacMetrics(ana.cval[0])
#mut.hu.getHegemonThrFrame(ana.dbid, l1[0])
# Out:
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [84, 305, 313]
# ['0.61', '0.98', '0.99']

# %%
reload(mut)
mut.plotHeatMapReactome()
# Out:
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [84, 305, 313]
# 85.50347222223506 63.80890052355557

# %%
reload(mut)
res = mut.learningAlgorithm()
# Out:
# [4228, 4200, 2, 3123, 3289, 168, 14, 4252, 440, 51, 30, 14, 4207, 4200, 2, 7516, 25, 116, 78, 74, 122, 142, 4198, 2, 4250, 66, 2, 8, 144, 107, 14]
# [4200, 3289, 168]
# [3213, 2448, 153]
# [-1, 1, 2]
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [6194, 5031, 313]
# [[-1, 1, 2], [1, 2, 3], ['0.53', '0.60', '0.71']]
# [4228, 4200, 2, 3123, 3289, 168, 14, 4252, 440, 51, 30, 14, 4207, 4200, 2, 7516, 25, 116, 78, 74, 122, 142, 4198, 2, 4250, 66, 2, 8, 144, 107, 14]
# [4200, 144, 168]
# [3213, 137, 153]
# [-1, 1, 2]
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [6194, 305, 313]
# [[-1, 1, 2], [1, 14, 3], ['0.51', '0.63', '0.72']]
# ...

# %%
res
# Out:
# ([[-1, 1, 2], [13, 14, 3], ['0.61', '0.98', '0.99']],
#  [[[-1, 1, 2], [1, 2, 3], ['0.53', '0.60', '0.71']],
#   [[-1, 1, 2], [1, 14, 3], ['0.51', '0.63', '0.72']],
#   [[-1, 1, 2], [10, 8, 9], ['0.51', '0.54', '0.58']],
#   [[-2, -1, 1], [11, 10, 8], ['0.77', '0.61', '0.90']],
#   [[-1, 1, 2], [12, 5, 6], ['0.65', '0.59', '0.94']],
#   [[-2, -1, 1], [1, 12, 5], ['0.50', '0.62', '0.67']],
#   [[-1, 1, 2], [13, 14, 3], ['0.61', '0.98', '0.99']]])

# %%
reload(mut)
mut.trainingAlgorithm()
# Out:
# [4228, 4200, 2, 3123, 3289, 168, 14, 4252, 440, 51, 30, 14, 4207, 4200, 2, 7516, 25, 116, 78, 74, 122, 142, 4198, 2, 4250, 66, 2, 8, 144, 107, 14]
# [4200, 3289, 168]
# [3215, 2448, 153]
# [-1, 1, 2]
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [6192, 5029, 313]
# Path 1-2-3 ['0.53', '0.60', '0.71']
# [4228, 4200, 2, 3123, 3289, 168, 14, 4252, 440, 51, 30, 14, 4207, 4200, 2, 7516, 25, 116, 78, 74, 122, 142, 4198, 2, 4250, 66, 2, 8, 144, 107, 14]
# [4200, 144, 168]
# [3215, 137, 153]
# [-1, 1, 2]
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [6192, 305, 313]
# Path 1-14-3 ['0.51', '0.63', '0.72']
# ...

# %%
reload(mut)
mut.comparativeAnalysis()
# Out:
# [4228, 4200, 2, 3123, 3289, 168, 14, 4252, 440, 51, 30, 14, 4207, 4200, 2, 7516, 25, 116, 78, 74, 122, 142, 4198, 2, 4250, 66, 2, 8, 144, 107, 14]
# [66, 144, 168]
# [48, 137, 153]
# [-1, 1, 2]
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [84, 305, 313]
# BoNE ['0.61', '0.98', '0.99']
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [152, 75]
# PMID: 26302899 ['0.64', '1.00', '0.96']
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [62, 75, 42]
# PMID: 26986567 ['0.78', '0.98', '0.63']
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# ...

# %%
reload(mut)
mut.validationAlgorithm()
# Out:
# [4228, 4200, 2, 3123, 3289, 168, 14, 4252, 440, 51, 30, 14, 4207, 4200, 2, 7516, 25, 116, 78, 74, 122, 142, 4198, 2, 4250, 66, 2, 8, 144, 107, 14]
# [66, 144, 168]
# [48, 137, 153]
# [-1, 1, 2]
# Human Macrophages 2012 (n = 197)
# GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16
# 68 [47, 13, 8] GEO http://hegemon.ucsd.edu/Tools/explore.php?key=gbm&id=G16 G16
# [84, 305, 313]
# 13-14-3 Pooled GSMs ['0.61', '0.98', '0.99']
# Beyer 2012 M0 M1 M2 Macrophages (n = 21)
# GSE35449 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC1
# 21 [7, 7, 7] GSE35449 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC1 MAC1
# [89, 241, 248]
# 13-14-3 GSE35449 ['0.54', '1.00', '0.96']
# Xue 2014 Macrophages (n = 384)
# GSE46903 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC2
# 133 [64, 29, 40] GSE46903 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC2 MAC2
# [89, 241, 248]
# 13-14-3 GSE46903 ['0.64', '0.97', '0.71']
# Ohradanova-Repic 2018 Mac (n = 21)
# ...

# %%
reload(mut)
import numpy as np
import pandas as pd
pdf = mut.getPDF("training-1.pdf")
list1 = ['GSE134312', 'GSE35449', 'GSE46903', 'GSE61298', 'GSE55536', 'GSE55536']

#C13
data1 = [[0.90,1.00,0.58],
[0.55,1.00,0.95],
[0.66,0.98,0.70],
[0.74,1.00,0.76],
[0.78,1.00,0.72],
[0.78,1.00,0.72]]

#C14-3
data2 = [[0.50,0.83,0.99],
[0.55,0.97,0.92],
[0.60,0.92,0.72],
[0.67,1.00,0.83],
[0.60,1.00,0.90],
[0.61,1.00,0.89]]

data3 = [ [data1[i][2], data2[i][2]] for i in range(6)]
data3 = np.array(data3)
order = np.argsort(data3[:, 0])[::-1]
data3 = np.array([data3[order,0],data3[order, 1]]).T
df = pd.DataFrame(data3)
df.columns = ['C13', 'C14-3']
df.index = [list1[i] for i in order]
ax = df.plot.bar(figsize=(2, 2*6/5))
ax.set_ylim([0.5, 1.1])
ax.set_title('M2')
pdf.savefig(transparent=True,bbox_inches = 'tight')

data3 = [ [data1[i][1], data2[i][1]] for i in range(6)]
data3 = np.array(data3)
#order = np.argsort(data3[:, 1])[::-1]
data3 = np.array([data3[order,0],data3[order, 1]]).T
df = pd.DataFrame(data3)
df.columns = ['C13', 'C14-3']
df.index = [list1[i] for i in order]
ax = df.plot.bar(figsize=(2, 2*6/5))
ax.set_ylim([0.5, 1.1])
ax.set_title('M1')
pdf.savefig(transparent=True,bbox_inches = 'tight')

mut.closePDF(pdf)

# %%
reload(mut)
mut.figure2a()
# Out:
# Rock 2005 Microglia (n = 24)
# GSE1432 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC73
# 24 [12, 12] GSE1432 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC73 MAC73
# [84, 255, 255]
# 13-14-3 Microglia (Brain) 0.89
# Polak 2014 skin Langerhans cells (n = 39)
# GSE49475 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC69
# 24 [12, 12] GSE49475 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC69 MAC69
# [146, 403, 442]
# 13-14-3 Langerhan’s (Skin) 0.99
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 13 [7, 6] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [84, 255, 255]
# 13-14-3 Colon, Sigmoid 1.00
# ImmGen ULI 2019 Mm (n = 890)
# GSE127267 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC81
# 4 [2, 2] GSE127267 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC81 MAC81
# [71, 109, 118]
# 13-14-3 Lung Lavage 1.00
# ...

# %%
reload(mut)
mut.figure2b()
# Out:
# Svensson 2011 fetal-maternal mac (n = 75)
# GSE30595 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC87
# 49 [22, 9, 18] GSE30595 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC87 MAC87
# [54, 63, 66]
# 13-14-3 Blood,Decidua,Preg 1.00 0.86
# Chandriani 2014 mac + lung fibroblast (n = 65)
# GSE47538 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC88
# 29 [10, 0, 19] GSE47538 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC88 MAC88
# [70, 199, 212]
# 13-14-3 Blood,Monocytes nan 0.88
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:813: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# Martinez 2015 Mac (n = 48)
# GSE55029 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC89
# 48 [15, 9, 24] GSE55029 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC89 MAC89
# [93, 246, 244]
# 13-14-3 PBMCs Macs 0.89 0.88
# Guler 2015 M0 M1 M2 Mm RMA (n = 36)
# ...

# %%
reload(mut)
mut.figure2c()
# Out:
# Jeffrey 2006 Mac Eos (n = 32)
# GSE3982 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV52
# 24 [18, 6] GSE3982 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV52 MACV52
# [84]
# 13 Mac, NK, DC, Eos, Bas 0.85
# Sippel 2018 Eosinophil (n = 18)
# GSE75142 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV53
# 18 [6, 12] GSE75142 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV53 MACV53
# [74]
# 13 Eosinophil 0.79
# Puan 2017 Basophil (n = 10)
# GSE70013 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV54
# 6 [3, 3] GSE70013 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV54 MACV54
# [53, 134, 147]
# 13-14-3 Basophil 1.00
# Klocperk 2020 Neutrophil TPM (n = 30)
# GSE143143 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV55
# 15 [5, 10] GSE143143 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV55 MACV55
# [48, 113, 128]
# 13-14-3 Neutrophil 0.88
# Lenardo 2020 tcell (n = 12)
# ...

# %%
reload(mut)
mut.figure2e()

# %%
reload(mut)
df = mut.MacDiseaseModel()
df.to_csv("mac-res-1.txt", sep="\t")
# Out:
# Peters 2017 IBD (n = 134)
# GSE83687 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP7
# 92 [60, 32] GSE83687 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP7 PLP7
# [48]
# [117, 130]
# [48, 117, 130]
# Peters 2017 IBD (n = 134)
# GSE83687 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP7
# 102 [60, 42] GSE83687 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP7 PLP7
# [48]
# [117, 130]
# [48, 117, 130]
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 13 [7, 6] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [84]
# [255, 255]
# [84, 255, 255]
# Qu 2016 Normal Adenoma Cancer (n = 58)
# GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50
# 24 [7, 17] GSE77953 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=PLP50 PLP50
# [84]
# [255, 255]
# [84, 255, 255]
# Qu 2016 Normal Adenoma Cancer (n = 58)
# ...

# %%
reload(mut)
mut.figure3p()
# Out:
# Tang 2020 mac Mm IL4 B6/BalbC (n = 25)
# GSE116105 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV95
# 13 [6, 7] GSE116105 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV95 MACV95
# [48]
# 13 GSE116105 0.90
# Link 2018 mac Mm (n = 32)
# GSE109965 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV98
# 8 [4, 4] GSE109965 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV98 MACV98
# [69]
# 13 GSE109965 1.00
# Howes 2016 mac Mm (n = 36)
# GSE79809 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV101
# 12 [6, 6] GSE79809 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV101 MACV101
# [96]
# 13 GSE79809 1.00

# %%
reload(mut)
df = mut.MacComparisonTransplantOutcome()
df.to_csv("mac-res-2.txt", sep="\t")
# Out:
# [82, 93]
# [34, 82, 93]
# [75, 37]
# [34, 32, 21]
# [44, 46]
# [95, 115]
# Morgun 2006 heart transplant II (n = 27)
# GSE4470 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV90
# 25 [13, 12] GSE4470 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV90 MACV90
# [34]
# [82, 93]
# [34, 82, 93]
# [75, 37]
# [34, 32, 21]
# [44, 46]
# [95, 115]
# Bohne 2012 liver 2 (n = 110)
# GSE26627 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV171
# 33 [24, 9] GSE26627 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV171 MACV171
# [89]
# [241, 248]
# [89, 241, 248]
# [180, 92]
# [60, 82, 56]
# [146, 93]
# [257, 295]
# Van Loon 2019 kidney blood (n = 212)
# GSE129166 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV88
# 95 [60, 35] GSE129166 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV88 MACV88
# [106]
# [361, 351]
# [106, 361, 351]
# [221, 119]
# [84, 125, 64]
# [237, 223]
# [473, 480]
# Palmer 2019 ibd blood (n = 176)
# ...

# %%
reload(mut)
df = mut.pd.read_csv("mac-res-2.txt", sep="\t", index_col=0)
res = mut.np.array_split(df, df.shape[0]/7, axis=0)

data = [list(k['ROC-AUC'] - 0.5) for k in res]
df = mut.pd.DataFrame(data)
df.columns = res[0]['Signature']
df.index = [k['Condition'][0] for k in res]
ax = df.plot.bar(color=mut.acolor[7:], figsize=(8, 4))
ax.legend(loc=(1.01,0.5))

# %%
reload(mut)
mut.figure4a()
# Out:
# JSTOM Colon (n = 612)
# GSE13067,GSE14333,GSE17538,GSE31595,GSE37892,GSE33113 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=CRC35.3
# 555 [415, 140] GSE13067,GSE14333,GSE17538,GSE31595,GSE37892,GSE33113 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=CRC35.3 CRC35.3
# [104, 432, 420]
# [-366.00049353232237, 207.97569754166895, -366.50049353232237, -365.50049353232237]
# [-475.5067559179694, 474.96172623041696, -476.0067559179694, -475.0067559179694]
# -366.00049353232237 15.35744059856853 38.48048808310365 -437.02626783486573
# /usr/local/lib/python3.6/dist-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
reload(mut)
mut.figure4b()
# Out:
# Hoshida 2013 Cir RMA (n = 216)
# GSE15654 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=LIV15.2
# 216 [150, 66] GSE15654 http://hegemon.ucsd.edu/Tools/explore.php?key=polyps&id=LIV15.2 LIV15.2
# [80, 197, 205]
# [-184.62868594282904, 143.06588201285533, -185.12868594282904, -184.12868594282904]
# -184.62868594282904 9.582862537736188 7.433594845448038 -177.195091097381
# /usr/local/lib/python3.6/dist-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
reload(mut)
mut.figure4c()
# Out:
# Scicluna 2015 Sepsis blood (n = 802)
# GSE65682 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC104
# 479 [365, 114] GSE65682 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC104 MAC104
# [146]
# [56.902427547611865, 191.41468053869275, 56.402427547611865, 57.402427547611865]
# [26.42292904128428, 517.2102526817083, 25.92292904128428, 26.92292904128428]
# 56.902427547611865 2.711886580474211 11.42292412127016 37.84585316255444
# /usr/local/lib/python3.6/dist-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
reload(mut)
mut.figure4d()
# Out:
# Herazo-Maya 2013 IPF I (n = 45)
# GSE28221 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV74
# 45 [30, 15] GSE28221 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV74 MACV74
# [89, 398, 386]
# [-807.8021095217157, 26.931909999923615, -808.3021095217157, -807.3021095217157] 33.74628102824737
# -807.8021095217157
# Herazo-Maya 2013 IPF II (n = 94)
# GSE28221 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV75
# 75 [32, 43] GSE28221 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV75 MACV75
# [79, 255, 253]
# [-319.09460479248634, 51.69405358138308, -319.59460479248634, -318.59460479248634] 17.70829414563149
# -345.6570460109336
# /usr/local/lib/python3.6/dist-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# ...

# %%
reload(mut)
mut.figure4e()
# Out:
# Einecke 2010 kidney transplant (n = 282)
# GSE21374 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV82
# 282 [231, 51] GSE21374 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV82 MACV82
# [106]
# [41.550733341143626, 162.11983180344328, 41.050733341143626, 42.050733341143626]
# 41.550733341143626 4.345710185670604 8.314333412435749 49.86506675357938
# /usr/local/lib/python3.6/dist-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
reload(mut)
mut.figure4f()
# Out:
# Zhang 2019 kidney transplant (n = 235)
# GSE112927 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV80
# 235 [205, 30] GSE112927 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV80 MACV80
# [48]
# [10.164892625203498, 110.43509629008065, 9.664892625203498, 10.664892625203498]
# 13.746316647580851 1.919693074977879 3.711854993597197 13.876747618800696
# /usr/local/lib/python3.6/dist-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
reload(mut)
mut.figure4g()
# Out:
# Kuparinen 2013 outcome (n = 151)
# GSE65218 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV120.2
# 151 [81, 70] GSE65218 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV120.2 MACV120.2
# [92, 219, 219]
# [-329.92369000867586, 60.23377651345235, -330.42369000867586, -329.42369000867586]
# -328.1607450456188 18.92572664793054 13.820337048371973 -316.1033529603039
# /usr/local/lib/python3.6/dist-packages/lifelines/fitters/kaplan_meier_fitter.py:268: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   self.confidence_interval_ = self._bounds(cumulative_sq_[:, None], alpha, ci_labels)
# ...

# %%
reload(mut)
mut.figure6()
# Out:
# Lee 2012 AIM2 HCT116 (n = 3)
# GSE24155 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV16
# 3 [1, 2] GSE24155 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV16 MACV16
# [104, 432, 420]
# 13-14-3 AIM2 OvExp 1.00
# Oakes 2017 OAS2 Hs (n = 11)
# GSE69397 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV19
# 6 [3, 3] GSE69397 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV19 MACV19
# [62, 123, 132]
# 13-14-3 Oas2 OvExp 1.00
# Wang 2019 IL15 Mac (n = 39)
# GSE132270 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV26
# 15 [3, 12] GSE132270 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV26 MACV26
# [48, 112, 125]
# 13-14-3 Il15/IL15R 1.00
# Man 2015 Irf1 Ifnar1 Aim2 Wt Mm (n = 8)
# GSE66461 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV4
# 4 [2, 0, 2] GSE66461 http://hegemon.ucsd.edu/Tools/explore.php?key=macv&id=MACV4 MACV4
# [66, 176, 130]
# 13-14-3 Irf1 -/- 1.00
# Fensterl 2012 brain VSV Ifit2 Mm (n = 4)
# ...

# %%
reload(mut)
mut.figure2f()
# Out:
# /usr/local/lib/python3.6/dist-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /usr/local/lib/python3.6/dist-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# [48]
# [113, 123]
# Counter({'IFNg+': 2419, 'Control': 62, 'IL4+': 1}) Counter({'Control': 5396, 'IFNg+': 2966, 'IL4+': 2829})
# (86.92614532040258, 0.0) 0.7245448415374242 0.010444743935309973 0.0003534817956875221
# 34.4129492993 -489.66071905294484

# %% [markdown]
# ## Figure S4

# %%
reload(mut)
wt1, l1 = mut.getCls14a3()
ana = mut.MacAnalysis()
ana.getDAmore2018()
ana.orderDataDf(l1, wt1)
fig = mut.plotViolinBar(ana, "Mac")
ana.normGene("DBP")
fig = mut.plotViolinBar(ana, "Mac")
# Out:
# D'Amore 2018 MetS (n = 40)
# GSE98895 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC114
# 40 [20, 20] GSE98895 http://hegemon.ucsd.edu/Tools/explore.php?key=mac&id=MAC114 MAC114
# [241, 248]
